# %%
import json
import time
import requests
from datetime import datetime
from sqlalchemy import create_engine, MetaData, Table, Column, String, Integer, DateTime, Float

# %% [markdown]
# # Define

# %%
stationUrls = [
    "A97507",
    "A21373",
    "A156526",
    "A74863",
    "A246697"
]

api_key = "d45fda67589e376593853b0fba950fc6d0dcbb65"

# %% [markdown]
# # Functions to get sensor data

# %%
def fetch_data_from_apis(api_key):
    sensor_data = []

    for station_id in stationUrls:  # Change variable from station_url to station_id
        api_url = f"https://api.waqi.info/feed/{station_id}/?token={api_key}"

        try:
            response = requests.get(api_url)

            if response.status_code == 200:
                api_data = response.json()
                print(f"API Response Data of station {station_id}: {json.dumps(api_data, indent=4)}")

                if api_data['status'] == 'ok':
                    station_info = api_data['data']
                    sensor_info = {
                        'api_timestamp': station_info['time']['v'],  # API timestamp
                        'etl_timestamp': int(datetime.now().timestamp()),  # Current timestamp
                        'location_address': station_info['city']['name'],  # City name
                        'location_coordinates': station_info['city']['geo'],  # Latitude and longitude
                        'name': station_info['city']['name'],  # Station name
                        'pm10': station_info['iaqi'].get('pm10', {}).get('v', None),  # PM10 value
                        'pm25': station_info['iaqi'].get('pm25', {}).get('v', None),  # PM2.5 value
                        'station_id': station_id,  # Station ID
                        'ui_url': f"https://aqicn.org/station/@{station_id}/",  # User interface URL
                        'url': api_url  # API request URL
                    }
                    sensor_data.append(sensor_info)
                else:
                    print(f"API responses do not contain the expected data structures, station: {station_id}")
            else:
                print(f"API request failed with status code: {response.status_code}，station: {station_id}")
        except Exception as e:
            print(f"Error when requesting API of station {station_id}: {e}")

    return sensor_data

# %% [markdown]
# # Functions to insert data into the database

# %%
def save_sensor_data_to_db(sensor_data):
    # Connect to the database using SQLAlchemy
    engine = create_engine('sqlite:///your_database.db')  # Replace with your actual database path
    metadata = MetaData()

    # Table schema
    pollution_sensor_data_table = Table(
        'pollution_sensor_data', metadata,
        Column('etl_timestamp', DateTime, primary_key=True, nullable=False),
        Column('station_id', String, primary_key=True, nullable=False),
        Column('api_timestamp', DateTime, nullable=False),
        Column('location_address', String, nullable=False),
        Column('latitude', Float, nullable=False),
        Column('longitude', Float, nullable=False),
        Column('name', String, nullable=False),
        Column('pm10', Integer, nullable=False),
        Column('pm25', Integer, nullable=False),
        Column('ui_url', String, nullable=False),
        Column('url', String, nullable=False)
    )

    metadata.create_all(engine)

    # Insert data into the table
    with engine.connect() as conn:
        for data in sensor_data:
            insert_stmt = pollution_sensor_data_table.insert().values(
                etl_timestamp=datetime.fromtimestamp(data['etl_timestamp']),
                station_id=data['station_id'],
                api_timestamp=datetime.fromtimestamp(data['api_timestamp']),
                location_address=data['location_address'],
                latitude=data['location_coordinates'][0],
                longitude=data['location_coordinates'][1],
                name=data['name'],
                pm10=data['pm10'],
                pm25=data['pm25'],
                ui_url=data['ui_url'],
                url=data['url']
            )
            conn.execute(insert_stmt)

# %% [markdown]
# # Execution

# %%
if __name__ == "__main__":
    while True:
        sensor_data = fetch_data_from_apis(api_key)
        print(sensor_data)  # Print the captured data

        if sensor_data:  # Only save if there is data
            save_sensor_data_to_db(sensor_data)
            print("Sensor data saved to database.")
        else:
            print("No sensor data to save.")

        time.sleep(300)  # Pause 5 minutes (300 seconds)
# Out:
# API Response Data of station A97507: {
#     "status": "ok",
#     "data": {
#         "aqi": 72,
#         "idx": -97507,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "40256"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.462,
#                 9.21
#             ],
#             "name": "Corso 22 Marzo",
#             "url": "https://aqicn.org/station/@97507",
#             "location": "Corso 22 Marzo, Ortica, Milan, Milano, Italy, 20135"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 33
#             },
#             "pm25": {
#                 "v": 72
#             }
#         },
#         "time": {
#             "s": "2024-10-15 19:58:46",
#             "tz": "+02:00",
#             "v": 1729015126,
#             "iso": "2024-10-15T17:58:46Z"
#         }
#     }
# }
# API Response Data of station A21373: {
#     "status": "error",
#     "data": "no such station"
# }
# API responses do not contain the expected data structures, station: A21373
# API Response Data of station A156526: {
#     "status": "ok",
#     "data": {
#         "aqi": 59,
#         "idx": -156526,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "50128"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.478,
#                 9.224
#             ],
#             "name": "Lambrate",
#             "url": "https://aqicn.org/station/@156526",
#             "location": "Tamoil, Lambrate, Milan, Milano, Italy"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 18
#             },
#             "pm25": {
#                 "v": 59
#             }
#         },
#         "time": {
#             "s": "2024-10-15 17:06:43",
#             "tz": "+02:00",
#             "v": 1729004803,
#             "iso": "2024-10-15T15:06:43Z"
#         }
#     }
# }
# API Response Data of station A74863: {
#     "status": "ok",
#     "data": {
#         "aqi": 125,
#         "idx": -74863,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "32393"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.426,
#                 9.206
#             ],
#             "name": "Via Federico Chopin",
#             "url": "https://aqicn.org/station/@74863",
#             "location": "Via Federico Chopin, Milan, Milano, Italy, 20141"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 56
#             },
#             "pm25": {
#                 "v": 125
#             }
#         },
#         "time": {
#             "s": "2024-10-15 19:56:38",
#             "tz": "+02:00",
#             "v": 1729014998,
#             "iso": "2024-10-15T17:56:38Z"
#         }
#     }
# }
# API Response Data of station A246697: {
#     "status": "ok",
#     "data": {
#         "aqi": 69,
#         "idx": -246697,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "70169"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.442,
#                 9.212
#             ],
#             "name": "Via Franco Albini",
#             "url": "https://aqicn.org/station/@246697",
#             "location": "Milan, Milano, Italy"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 36
#             },
#             "pm25": {
#                 "v": 69
#             }
#         },
#         "time": {
#             "s": "2024-10-15 19:58:59",
#             "tz": "+02:00",
#             "v": 1729015139,
#             "iso": "2024-10-15T17:58:59Z"
#         }
#     }
# }
# [{'api_timestamp': 1729015126, 'etl_timestamp': 1729015333, 'location_address': 'Corso 22 Marzo', 'location_coordinates': [45.462, 9.21], 'name': 'Corso 22 Marzo', 'pm10': 33, 'pm25': 72, 'station_id': 'A97507', 'ui_url': 'https://aqicn.org/station/@A97507/', 'url': 'https://api.waqi.info/feed/A97507/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729004803, 'etl_timestamp': 1729015334, 'location_address': 'Lambrate', 'location_coordinates': [45.478, 9.224], 'name': 'Lambrate', 'pm10': 18, 'pm25': 59, 'station_id': 'A156526', 'ui_url': 'https://aqicn.org/station/@A156526/', 'url': 'https://api.waqi.info/feed/A156526/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729014998, 'etl_timestamp': 1729015335, 'location_address': 'Via Federico Chopin', 'location_coordinates': [45.426, 9.206], 'name': 'Via Federico Chopin', 'pm10': 56, 'pm25': 125, 'station_id': 'A74863', 'ui_url': 'https://aqicn.org/station/@A74863/', 'url': 'https://api.waqi.info/feed/A74863/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729015139, 'etl_timestamp': 1729015336, 'location_address': 'Via Franco Albini', 'location_coordinates': [45.442, 9.212], 'name': 'Via Franco Albini', 'pm10': 36, 'pm25': 69, 'station_id': 'A246697', 'ui_url': 'https://aqicn.org/station/@A246697/', 'url': 'https://api.waqi.info/feed/A246697/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}]
# Sensor data saved to database.
# API Response Data of station A97507: {
#     "status": "ok",
#     "data": {
#         "aqi": 69,
#         "idx": -97507,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "40256"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.462,
#                 9.21
#             ],
#             "name": "Corso 22 Marzo",
#             "url": "https://aqicn.org/station/@97507",
#             "location": "Corso 22 Marzo, Ortica, Milan, Milano, Italy, 20135"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 31
#             },
#             "pm25": {
#                 "v": 69
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:03:38",
#             "tz": "+02:00",
#             "v": 1729015418,
#             "iso": "2024-10-15T18:03:38Z"
#         }
#     }
# }
# API Response Data of station A21373: {
#     "status": "error",
#     "data": "no such station"
# }
# API responses do not contain the expected data structures, station: A21373
# API Response Data of station A156526: {
#     "status": "ok",
#     "data": {
#         "aqi": 59,
#         "idx": -156526,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "50128"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.478,
#                 9.224
#             ],
#             "name": "Lambrate",
#             "url": "https://aqicn.org/station/@156526",
#             "location": "Tamoil, Lambrate, Milan, Milano, Italy"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 18
#             },
#             "pm25": {
#                 "v": 59
#             }
#         },
#         "time": {
#             "s": "2024-10-15 17:06:43",
#             "tz": "+02:00",
#             "v": 1729004803,
#             "iso": "2024-10-15T15:06:43Z"
#         }
#     }
# }
# API Response Data of station A74863: {
#     "status": "ok",
#     "data": {
#         "aqi": 126,
#         "idx": -74863,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "32393"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.426,
#                 9.206
#             ],
#             "name": "Via Federico Chopin",
#             "url": "https://aqicn.org/station/@74863",
#             "location": "Via Federico Chopin, Milan, Milano, Italy, 20141"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 56
#             },
#             "pm25": {
#                 "v": 126
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:01:55",
#             "tz": "+02:00",
#             "v": 1729015315,
#             "iso": "2024-10-15T18:01:55Z"
#         }
#     }
# }
# API Response Data of station A246697: {
#     "status": "ok",
#     "data": {
#         "aqi": 70,
#         "idx": -246697,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "70169"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.442,
#                 9.212
#             ],
#             "name": "Via Franco Albini",
#             "url": "https://aqicn.org/station/@246697",
#             "location": "Milan, Milano, Italy"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 37
#             },
#             "pm25": {
#                 "v": 70
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:02:03",
#             "tz": "+02:00",
#             "v": 1729015323,
#             "iso": "2024-10-15T18:02:03Z"
#         }
#     }
# }
# [{'api_timestamp': 1729015418, 'etl_timestamp': 1729015637, 'location_address': 'Corso 22 Marzo', 'location_coordinates': [45.462, 9.21], 'name': 'Corso 22 Marzo', 'pm10': 31, 'pm25': 69, 'station_id': 'A97507', 'ui_url': 'https://aqicn.org/station/@A97507/', 'url': 'https://api.waqi.info/feed/A97507/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729004803, 'etl_timestamp': 1729015638, 'location_address': 'Lambrate', 'location_coordinates': [45.478, 9.224], 'name': 'Lambrate', 'pm10': 18, 'pm25': 59, 'station_id': 'A156526', 'ui_url': 'https://aqicn.org/station/@A156526/', 'url': 'https://api.waqi.info/feed/A156526/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729015315, 'etl_timestamp': 1729015639, 'location_address': 'Via Federico Chopin', 'location_coordinates': [45.426, 9.206], 'name': 'Via Federico Chopin', 'pm10': 56, 'pm25': 126, 'station_id': 'A74863', 'ui_url': 'https://aqicn.org/station/@A74863/', 'url': 'https://api.waqi.info/feed/A74863/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729015323, 'etl_timestamp': 1729015639, 'location_address': 'Via Franco Albini', 'location_coordinates': [45.442, 9.212], 'name': 'Via Franco Albini', 'pm10': 37, 'pm25': 70, 'station_id': 'A246697', 'ui_url': 'https://aqicn.org/station/@A246697/', 'url': 'https://api.waqi.info/feed/A246697/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}]
# Sensor data saved to database.
# API Response Data of station A97507: {
#     "status": "ok",
#     "data": {
#         "aqi": 72,
#         "idx": -97507,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "40256"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.462,
#                 9.21
#             ],
#             "name": "Corso 22 Marzo",
#             "url": "https://aqicn.org/station/@97507",
#             "location": "Corso 22 Marzo, Ortica, Milan, Milano, Italy, 20135"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 35
#             },
#             "pm25": {
#                 "v": 72
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:08:36",
#             "tz": "+02:00",
#             "v": 1729015716,
#             "iso": "2024-10-15T18:08:36Z"
#         }
#     }
# }
# API Response Data of station A21373: {
#     "status": "error",
#     "data": "no such station"
# }
# API responses do not contain the expected data structures, station: A21373
# API Response Data of station A156526: {
#     "status": "ok",
#     "data": {
#         "aqi": 59,
#         "idx": -156526,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "50128"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.478,
#                 9.224
#             ],
#             "name": "Lambrate",
#             "url": "https://aqicn.org/station/@156526",
#             "location": "Tamoil, Lambrate, Milan, Milano, Italy"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 18
#             },
#             "pm25": {
#                 "v": 59
#             }
#         },
#         "time": {
#             "s": "2024-10-15 17:06:43",
#             "tz": "+02:00",
#             "v": 1729004803,
#             "iso": "2024-10-15T15:06:43Z"
#         }
#     }
# }
# API Response Data of station A74863: {
#     "status": "ok",
#     "data": {
#         "aqi": 121,
#         "idx": -74863,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "32393"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.426,
#                 9.206
#             ],
#             "name": "Via Federico Chopin",
#             "url": "https://aqicn.org/station/@74863",
#             "location": "Via Federico Chopin, Milan, Milano, Italy, 20141"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 55
#             },
#             "pm25": {
#                 "v": 121
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:09:16",
#             "tz": "+02:00",
#             "v": 1729015756,
#             "iso": "2024-10-15T18:09:16Z"
#         }
#     }
# }
# API Response Data of station A246697: {
#     "status": "ok",
#     "data": {
#         "aqi": 72,
#         "idx": -246697,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "70169"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.442,
#                 9.212
#             ],
#             "name": "Via Franco Albini",
#             "url": "https://aqicn.org/station/@246697",
#             "location": "Milan, Milano, Italy"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 37
#             },
#             "pm25": {
#                 "v": 72
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:08:14",
#             "tz": "+02:00",
#             "v": 1729015694,
#             "iso": "2024-10-15T18:08:14Z"
#         }
#     }
# }
# [{'api_timestamp': 1729015716, 'etl_timestamp': 1729015940, 'location_address': 'Corso 22 Marzo', 'location_coordinates': [45.462, 9.21], 'name': 'Corso 22 Marzo', 'pm10': 35, 'pm25': 72, 'station_id': 'A97507', 'ui_url': 'https://aqicn.org/station/@A97507/', 'url': 'https://api.waqi.info/feed/A97507/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729004803, 'etl_timestamp': 1729015941, 'location_address': 'Lambrate', 'location_coordinates': [45.478, 9.224], 'name': 'Lambrate', 'pm10': 18, 'pm25': 59, 'station_id': 'A156526', 'ui_url': 'https://aqicn.org/station/@A156526/', 'url': 'https://api.waqi.info/feed/A156526/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729015756, 'etl_timestamp': 1729015942, 'location_address': 'Via Federico Chopin', 'location_coordinates': [45.426, 9.206], 'name': 'Via Federico Chopin', 'pm10': 55, 'pm25': 121, 'station_id': 'A74863', 'ui_url': 'https://aqicn.org/station/@A74863/', 'url': 'https://api.waqi.info/feed/A74863/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729015694, 'etl_timestamp': 1729015943, 'location_address': 'Via Franco Albini', 'location_coordinates': [45.442, 9.212], 'name': 'Via Franco Albini', 'pm10': 37, 'pm25': 72, 'station_id': 'A246697', 'ui_url': 'https://aqicn.org/station/@A246697/', 'url': 'https://api.waqi.info/feed/A246697/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}]
# Sensor data saved to database.
# API Response Data of station A97507: {
#     "status": "ok",
#     "data": {
#         "aqi": 67,
#         "idx": -97507,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "40256"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.462,
#                 9.21
#             ],
#             "name": "Corso 22 Marzo",
#             "url": "https://aqicn.org/station/@97507",
#             "location": "Corso 22 Marzo, Ortica, Milan, Milano, Italy, 20135"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 30
#             },
#             "pm25": {
#                 "v": 67
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:15:53",
#             "tz": "+02:00",
#             "v": 1729016153,
#             "iso": "2024-10-15T18:15:53Z"
#         }
#     }
# }
# API Response Data of station A21373: {
#     "status": "error",
#     "data": "no such station"
# }
# API responses do not contain the expected data structures, station: A21373
# API Response Data of station A156526: {
#     "status": "ok",
#     "data": {
#         "aqi": 59,
#         "idx": -156526,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "50128"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.478,
#                 9.224
#             ],
#             "name": "Lambrate",
#             "url": "https://aqicn.org/station/@156526",
#             "location": "Tamoil, Lambrate, Milan, Milano, Italy"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 18
#             },
#             "pm25": {
#                 "v": 59
#             }
#         },
#         "time": {
#             "s": "2024-10-15 17:06:43",
#             "tz": "+02:00",
#             "v": 1729004803,
#             "iso": "2024-10-15T15:06:43Z"
#         }
#     }
# }
# API Response Data of station A74863: {
#     "status": "ok",
#     "data": {
#         "aqi": 123,
#         "idx": -74863,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "32393"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.426,
#                 9.206
#             ],
#             "name": "Via Federico Chopin",
#             "url": "https://aqicn.org/station/@74863",
#             "location": "Via Federico Chopin, Milan, Milano, Italy, 20141"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 54
#             },
#             "pm25": {
#                 "v": 123
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:14:08",
#             "tz": "+02:00",
#             "v": 1729016048,
#             "iso": "2024-10-15T18:14:08Z"
#         }
#     }
# }
# API Response Data of station A246697: {
#     "status": "ok",
#     "data": {
#         "aqi": 70,
#         "idx": -246697,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "70169"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.442,
#                 9.212
#             ],
#             "name": "Via Franco Albini",
#             "url": "https://aqicn.org/station/@246697",
#             "location": "Milan, Milano, Italy"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 39
#             },
#             "pm25": {
#                 "v": 70
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:14:23",
#             "tz": "+02:00",
#             "v": 1729016063,
#             "iso": "2024-10-15T18:14:23Z"
#         }
#     }
# }
# [{'api_timestamp': 1729016153, 'etl_timestamp': 1729016243, 'location_address': 'Corso 22 Marzo', 'location_coordinates': [45.462, 9.21], 'name': 'Corso 22 Marzo', 'pm10': 30, 'pm25': 67, 'station_id': 'A97507', 'ui_url': 'https://aqicn.org/station/@A97507/', 'url': 'https://api.waqi.info/feed/A97507/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729004803, 'etl_timestamp': 1729016245, 'location_address': 'Lambrate', 'location_coordinates': [45.478, 9.224], 'name': 'Lambrate', 'pm10': 18, 'pm25': 59, 'station_id': 'A156526', 'ui_url': 'https://aqicn.org/station/@A156526/', 'url': 'https://api.waqi.info/feed/A156526/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729016048, 'etl_timestamp': 1729016245, 'location_address': 'Via Federico Chopin', 'location_coordinates': [45.426, 9.206], 'name': 'Via Federico Chopin', 'pm10': 54, 'pm25': 123, 'station_id': 'A74863', 'ui_url': 'https://aqicn.org/station/@A74863/', 'url': 'https://api.waqi.info/feed/A74863/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729016063, 'etl_timestamp': 1729016246, 'location_address': 'Via Franco Albini', 'location_coordinates': [45.442, 9.212], 'name': 'Via Franco Albini', 'pm10': 39, 'pm25': 70, 'station_id': 'A246697', 'ui_url': 'https://aqicn.org/station/@A246697/', 'url': 'https://api.waqi.info/feed/A246697/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}]
# Sensor data saved to database.
# API Response Data of station A97507: {
#     "status": "ok",
#     "data": {
#         "aqi": 68,
#         "idx": -97507,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "40256"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.462,
#                 9.21
#             ],
#             "name": "Corso 22 Marzo",
#             "url": "https://aqicn.org/station/@97507",
#             "location": "Corso 22 Marzo, Ortica, Milan, Milano, Italy, 20135"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 38
#             },
#             "pm25": {
#                 "v": 68
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:20:46",
#             "tz": "+02:00",
#             "v": 1729016446,
#             "iso": "2024-10-15T18:20:46Z"
#         }
#     }
# }
# API Response Data of station A21373: {
#     "status": "error",
#     "data": "no such station"
# }
# API responses do not contain the expected data structures, station: A21373
# API Response Data of station A156526: {
#     "status": "ok",
#     "data": {
#         "aqi": 59,
#         "idx": -156526,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "50128"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.478,
#                 9.224
#             ],
#             "name": "Lambrate",
#             "url": "https://aqicn.org/station/@156526",
#             "location": "Tamoil, Lambrate, Milan, Milano, Italy"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 18
#             },
#             "pm25": {
#                 "v": 59
#             }
#         },
#         "time": {
#             "s": "2024-10-15 17:06:43",
#             "tz": "+02:00",
#             "v": 1729004803,
#             "iso": "2024-10-15T15:06:43Z"
#         }
#     }
# }
# API Response Data of station A74863: {
#     "status": "ok",
#     "data": {
#         "aqi": 120,
#         "idx": -74863,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "32393"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.426,
#                 9.206
#             ],
#             "name": "Via Federico Chopin",
#             "url": "https://aqicn.org/station/@74863",
#             "location": "Via Federico Chopin, Milan, Milano, Italy, 20141"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 53
#             },
#             "pm25": {
#                 "v": 120
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:19:01",
#             "tz": "+02:00",
#             "v": 1729016341,
#             "iso": "2024-10-15T18:19:01Z"
#         }
#     }
# }
# API Response Data of station A246697: {
#     "status": "ok",
#     "data": {
#         "aqi": 67,
#         "idx": -246697,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "70169"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.442,
#                 9.212
#             ],
#             "name": "Via Franco Albini",
#             "url": "https://aqicn.org/station/@246697",
#             "location": "Milan, Milano, Italy"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 34
#             },
#             "pm25": {
#                 "v": 67
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:20:31",
#             "tz": "+02:00",
#             "v": 1729016431,
#             "iso": "2024-10-15T18:20:31Z"
#         }
#     }
# }
# [{'api_timestamp': 1729016446, 'etl_timestamp': 1729016547, 'location_address': 'Corso 22 Marzo', 'location_coordinates': [45.462, 9.21], 'name': 'Corso 22 Marzo', 'pm10': 38, 'pm25': 68, 'station_id': 'A97507', 'ui_url': 'https://aqicn.org/station/@A97507/', 'url': 'https://api.waqi.info/feed/A97507/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729004803, 'etl_timestamp': 1729016548, 'location_address': 'Lambrate', 'location_coordinates': [45.478, 9.224], 'name': 'Lambrate', 'pm10': 18, 'pm25': 59, 'station_id': 'A156526', 'ui_url': 'https://aqicn.org/station/@A156526/', 'url': 'https://api.waqi.info/feed/A156526/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729016341, 'etl_timestamp': 1729016549, 'location_address': 'Via Federico Chopin', 'location_coordinates': [45.426, 9.206], 'name': 'Via Federico Chopin', 'pm10': 53, 'pm25': 120, 'station_id': 'A74863', 'ui_url': 'https://aqicn.org/station/@A74863/', 'url': 'https://api.waqi.info/feed/A74863/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729016431, 'etl_timestamp': 1729016549, 'location_address': 'Via Franco Albini', 'location_coordinates': [45.442, 9.212], 'name': 'Via Franco Albini', 'pm10': 34, 'pm25': 67, 'station_id': 'A246697', 'ui_url': 'https://aqicn.org/station/@A246697/', 'url': 'https://api.waqi.info/feed/A246697/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}]
# Sensor data saved to database.
# API Response Data of station A97507: {
#     "status": "ok",
#     "data": {
#         "aqi": 70,
#         "idx": -97507,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "40256"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.462,
#                 9.21
#             ],
#             "name": "Corso 22 Marzo",
#             "url": "https://aqicn.org/station/@97507",
#             "location": "Corso 22 Marzo, Ortica, Milan, Milano, Italy, 20135"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 32
#             },
#             "pm25": {
#                 "v": 70
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:23:12",
#             "tz": "+02:00",
#             "v": 1729016592,
#             "iso": "2024-10-15T18:23:12Z"
#         }
#     }
# }
# API Response Data of station A21373: {
#     "status": "error",
#     "data": "no such station"
# }
# API responses do not contain the expected data structures, station: A21373
# API Response Data of station A156526: {
#     "status": "ok",
#     "data": {
#         "aqi": 59,
#         "idx": -156526,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "50128"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.478,
#                 9.224
#             ],
#             "name": "Lambrate",
#             "url": "https://aqicn.org/station/@156526",
#             "location": "Tamoil, Lambrate, Milan, Milano, Italy"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 18
#             },
#             "pm25": {
#                 "v": 59
#             }
#         },
#         "time": {
#             "s": "2024-10-15 17:06:43",
#             "tz": "+02:00",
#             "v": 1729004803,
#             "iso": "2024-10-15T15:06:43Z"
#         }
#     }
# }
# API Response Data of station A74863: {
#     "status": "ok",
#     "data": {
#         "aqi": 116,
#         "idx": -74863,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "32393"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.426,
#                 9.206
#             ],
#             "name": "Via Federico Chopin",
#             "url": "https://aqicn.org/station/@74863",
#             "location": "Via Federico Chopin, Milan, Milano, Italy, 20141"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 53
#             },
#             "pm25": {
#                 "v": 116
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:23:53",
#             "tz": "+02:00",
#             "v": 1729016633,
#             "iso": "2024-10-15T18:23:53Z"
#         }
#     }
# }
# API Response Data of station A246697: {
#     "status": "ok",
#     "data": {
#         "aqi": 66,
#         "idx": -246697,
#         "attributions": [
#             {
#                 "url": "https://sensor.community/",
#                 "name": "Citizen Science project sensor.community",
#                 "station": "70169"
#             },
#             {
#                 "url": "https://waqi.info/",
#                 "name": "World Air Quality Index Project"
#             }
#         ],
#         "city": {
#             "geo": [
#                 45.442,
#                 9.212
#             ],
#             "name": "Via Franco Albini",
#             "url": "https://aqicn.org/station/@246697",
#             "location": "Milan, Milano, Italy"
#         },
#         "dominentpol": "pm25",
#         "iaqi": {
#             "pm10": {
#                 "v": 32
#             },
#             "pm25": {
#                 "v": 66
#             }
#         },
#         "time": {
#             "s": "2024-10-15 20:23:35",
#             "tz": "+02:00",
#             "v": 1729016615,
#             "iso": "2024-10-15T18:23:35Z"
#         }
#     }
# }
# [{'api_timestamp': 1729016592, 'etl_timestamp': 1729016850, 'location_address': 'Corso 22 Marzo', 'location_coordinates': [45.462, 9.21], 'name': 'Corso 22 Marzo', 'pm10': 32, 'pm25': 70, 'station_id': 'A97507', 'ui_url': 'https://aqicn.org/station/@A97507/', 'url': 'https://api.waqi.info/feed/A97507/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729004803, 'etl_timestamp': 1729016851, 'location_address': 'Lambrate', 'location_coordinates': [45.478, 9.224], 'name': 'Lambrate', 'pm10': 18, 'pm25': 59, 'station_id': 'A156526', 'ui_url': 'https://aqicn.org/station/@A156526/', 'url': 'https://api.waqi.info/feed/A156526/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729016633, 'etl_timestamp': 1729016852, 'location_address': 'Via Federico Chopin', 'location_coordinates': [45.426, 9.206], 'name': 'Via Federico Chopin', 'pm10': 53, 'pm25': 116, 'station_id': 'A74863', 'ui_url': 'https://aqicn.org/station/@A74863/', 'url': 'https://api.waqi.info/feed/A74863/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}, {'api_timestamp': 1729016615, 'etl_timestamp': 1729016853, 'location_address': 'Via Franco Albini', 'location_coordinates': [45.442, 9.212], 'name': 'Via Franco Albini', 'pm10': 32, 'pm25': 66, 'station_id': 'A246697', 'ui_url': 'https://aqicn.org/station/@A246697/', 'url': 'https://api.waqi.info/feed/A246697/?token=d45fda67589e376593853b0fba950fc6d0dcbb65'}]
# Sensor data saved to database.
